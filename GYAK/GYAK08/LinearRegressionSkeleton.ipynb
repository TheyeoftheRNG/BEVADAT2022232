# %%
from LinearRegressionSkeleton import LinearRegression

sample = LinearRegression(1000,0.0001)

sample.fit()

# %%
sample.fit()

# %%
sample.predict()
# Out:
# [1.522378946301216, 0.5853240266268058, 2.2095525540624505, 1.459908618322922, 1.553614110290363, 0.5228536986485118, 1.178792142420599, 1.6473196022578038, 1.459908618322922, 1.2724976343880399, 1.6473196022578038, 0.4916185346593647, 0.4603833706702178, 0.5228536986485118, 0.5228536986485118, 1.522378946301216, 1.865965750181833, 1.2724976343880399, 1.459908618322922, 1.8034954222035389, 0.5540888626376589, 1.5848492742795102, 0.5540888626376589, 1.8034954222035389, 2.0533767341167155, 1.678554766246951, 1.865965750181833, 1.8972009141709802, 0.4916185346593647, 0.5540888626376589]
# [1.2 0.3 2.3 1.5 1.4 0.4 1.3 2.3 1.5 1.2 2.  0.1 0.2 0.1 0.3 1.6 2.2 1.1
#  1.3 2.2 0.2 1.8 0.4 2.1 2.  2.3 1.8 2.3 0.3 0.2]

# %%
sample.evaluate()
# Out:
# Mean Absolute Error: 0.24670899817437747
# Mean Squared Error: 0.08621970717466496
